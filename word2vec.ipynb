# %% [markdown]
# # 基于tensorflow实现word2vec

# %%
import collections
import os
import random
import urllib
import zipfile
import numpy as np
import tensorflow as tf

# %%
# 微调参数
learning_rate = 0.1
batch_size = 128
num_steps = 1000000
display_step = 20000
eval_step = 100000

# 测试样例
eval_words = ['nine', 'of', 'going', 'girl', 'love']

# Word2Vec参数
embedding_size = 200 # 词向量维度
max_vocabulary_size = 50000  # 语料库词语数
min_occurrence = 10 # 最小词频，少于这个数的不要
skip_window = 3     # 左右窗口大小，两边是3*2，加一个训练词，窗口是7
num_skips = 2     # 一次制作多少个输入输出对
num_sampled = 64     # 负采样

# %%
# 加载训练数据，什么数据都可以
data_path = "./data/test.txt"
with open(data_path, 'rb') as f:
    text_words = f.read().lower().split()

# %%
len(text_words)
# Out:
# 1367297

# %%
# 创建一个计数器，计算每个词出现了多少次
count = [('UNK', -1)]
# 基于词频返回max_vocabulary_size个常用词
count.extend(collections.Counter(text_words).most_common(max_vocabulary_size-1))

# %%
count[:10]
# Out:
# [('UNK', -1),
#  (b'the', 57024),
#  (b'to', 41289),
#  (b'and', 39944),
#  (b'of', 35950),
#  (b'a', 28947),
#  (b'i', 28097),
#  (b'in', 22601),
#  (b'that', 17328),
#  (b'he', 17089)]

# %%
# 剔除掉出现次数少于min_occurrence
for i in range(len(count)-1, -1, -1):    # 从start到end每次step多少
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        # 判断是，从小到大排序得，所以跳出得时候剩下得都是满足条件的
        break

# %%
len(count)
# Out:
# 9178

# %% [markdown]
# # 词-ID映射

# %%
# 计算语料库大小
vocabulary_size = len(count)
# 每个词都分配一个id
word2id = dict()
for i, (word, _) in enumerate(count):
    word2id[word] = i

# %%
word2id
# Out:
# {'UNK': 0,
#  b'the': 1,
#  b'to': 2,
#  b'and': 3,
#  b'of': 4,
#  b'a': 5,
#  b'i': 6,
#  b'in': 7,
#  b'that': 8,
#  b'he': 9,
#  b'was': 10,
#  b'his': 11,
#  b'with': 12,
#  b'it': 13,
#  b'had': 14,
#  b'as': 15,
#  b'her': 16,
#  b'my': 17,
#  b'you': 18,
#  b'for': 19,
#  b'have': 20,
#  b'at': 21,
#  b'she': 22,
#  b'be': 23,
#  b'not': 24,
#  b'is': 25,
#  b'but': 26,
#  b'on': 27,
#  b'mr.': 28,
#  b'which': 29,
#  b'said': 30,
#  b'this': 31,
#  b'by': 32,
#  b'so': 33,
#  b'all': 34,
#  b'me': 35,
#  b'from': 36,
#  b'if': 37,
#  b'him': 38,
#  b'would': 39,
#  b'when': 40,
#  b'been': 41,
#  b'what': 42,
#  b'we': 43,
#  b'an': 44,
#  b'no': 45,
#  b'very': 46,
#  b'were': 47,
#  b'or': 48,
#  b'who': 49,
#  b'will': 50,
#  b'are': 51,
#  b'little': 52,
#  b'any': 53,
#  b'your': 54,
#  b'they': 55,
#  b'than': 56,
#  b'there': 57,
#  b'one': 58,
#  b'more': 59,
#  b'could': 60,
#  b'some': 61,
#  b'into': 62,
#  b'am': 63,
#  b'out': 64,
#  b'should': 65,
#  b'never': 66,
#  b'do': 67,
#  b'upon': 68,
#  b'much': 69,
#  b'such': 70,
#  b'up': 71,
#  b'about': 72,
#  b'their': 73,
#  b'good': 74,
#  b'know': 75,
#  b'has': 76,
#  b'mrs.': 77,
#  b'like': 78,
#  b'now': 79,
#  b'being': 80,
#  b'may': 81,
#  b'"i': 82,
#  b'our': 83,
#  b'must': 84,
#  b'me,': 85,
#  b'made': 86,
#  b'old': 87,
#  b'before': 88,
#  b'can': 89,
#  b'might': 90,
#  b'great': 91,
#  b'think': 92,
#  b'only': 93,
#  b'own': 94,
#  b'other': 95,
#  b'did': 96,
#  b'see': 97,
#  b'after': 98,
#  b'man': 99,
#  b'it,': 100,
#  b'then': 101,
#  b'them': 102,
#  b'how': 103,
#  b'come': 104,
#  b'young': 105,
#  b'without': 106,
#  b'say': 107,
#  b'him,': 108,
#  b'time': 109,
#  b'these': 110,
#  b'make': 111,
#  b'says': 112,
#  b'miss': 113,
#  b'shall': 114,
#  b'where': 115,
#  b'down': 116,
#  b'thought': 117,
#  b'ever': 118,
#  b'himself': 119,
#  b'go': 120,
#  b'though': 121,
#  b'most': 122,
#  b'well': 123,
#  b'always': 124,
#  b'you,': 125,
#  b'mr': 126,
#  b'came': 127,
#  b'it.': 128,
#  b'many': 129,
#  b'went': 130,
#  b'over': 131,
#  b'those': 132,
#  b'first': 133,
#  b'take': 134,
#  b'two': 135,
#  b'said,': 136,
#  b'her,': 137,
#  b'too': 138,
#  b'quite': 139,
#  b'having': 140,
#  b'lady': 141,
#  b"don't": 142,
#  b'us': 143,
#  b'nothing': 144,
#  b'even': 145,
#  b'its': 146,
#  b'poor': 147,
#  b'looking': 148,
#  b'put': 149,
#  b'long': 150,
#  b'same': 151,
#  b'dear': 152,
#  b'going': 153,
#  b'here': 154,
#  b'better': 155,
#  b'every': 156,
#  b'while': 157,
#  b'saw': 158,
#  b'him.': 159,
#  b'looked': 160,
#  b'\xe2\x80\x98i': 161,
#  b'look': 162,
#  b'tell': 163,
#  b'me.': 164,
#  b'way': 165,
#  b'seemed': 166,
#  b'last': 167,
#  b'give': 168,
#  b'took': 169,
#  b'found': 170,
#  b'told': 171,
#  b'jones': 172,
#  b'anything': 173,
#  b'another': 174,
#  b'got': 175,
#  b'something': 176,
#  b'yet': 177,
#  b'through': 178,
#  b'whom': 179,
#  b'mind': 180,
#  b'felt': 181,
#  b'still': 182,
#  b'rather': 183,
#  b'away': 184,
#  b'against': 185,
#  b'between': 186,
#  b'back': 187,
#  b'under': 188,
#  b'sir': 189,
#  b'knew': 190,
#  b'now,': 191,
#  b'both': 192,
#  b'head': 193,
#  b'\xe2\x80\x9ci': 194,
#  b'towards': 195,
#  b'myself': 196,
#  b'left': 197,
#  b'eyes': 198,
#  b'let': 199,
#  b'seen': 200,
#  b'hand': 201,
#  b'mrs': 202,
#  b'sure': 203,
#  b'just': 204,
#  b'house': 205,
#  b'find': 206,
#  b'heard': 207,
#  b'day': 208,
#  b'face': 209,
#  b'hath': 210,
#  b'again': 211,
#  b'whole': 212,
#  b'love': 213,
#  b'gave': 214,
#  b'"you': 215,
#  b'done': 216,
#  b'soon': 217,
#  b'herself': 218,
#  b'new': 219,
#  b'returned': 220,
#  b'nor': 221,
#  b'get': 222,
#  b'once': 223,
#  b'part': 224,
#  b'perhaps': 225,
#  b'because': 226,
#  b'since': 227,
#  b'cries': 228,
#  b'people': 229,
#  b'jones,': 230,
#  b'off': 231,
#  b'began': 232,
#  b'answered': 233,
#  b'whether': 234,
#  b'life': 235,
#  b'often': 236,
#  b'her.': 237,
#  b'kind': 238,
#  b'enough': 239,
#  b'really': 240,
#  b'brought': 241,
#  b'that,': 242,
#  b'believe': 243,
#  b'sir,': 244,
#  b'best': 245,
#  b'want': 246,
#  b'among': 247,
#  b'lydgate': 248,
#  b'present': 249,
#  b'indeed,': 250,
#  b'less': 251,
#  b'place': 252,
#  b'sat': 253,
#  b'woman': 254,
#  b'say,': 255,
#  b'almost': 256,
#  b'taken': 257,
#  b'called': 258,
#  b'indeed': 259,
#  b'turned': 260,
#  b'again,': 261,
#  b'whose': 262,
#  b'few': 263,
#  b'hope': 264,
#  b'was,': 265,
#  b'right': 266,
#  b'and,': 267,
#  b'hear': 268,
#  b'least': 269,
#  b'round': 270,
#  b'gentleman': 271,
#  b'leave': 272,
#  b'wish': 273,
#  b'is,': 274,
#  b'men': 275,
#  b'set': 276,
#  b'things': 277,
#  b'"and': 278,
#  b'name': 279,
#  b'chapter': 280,
#  b'next': 281,
#  b'making': 282,
#  b'time,': 283,
#  b'them,': 284,
#  b'however,': 285,
#  b'hands': 286,
#  b'three': 287,
#  b'asked': 288,
#  b'half': 289,
#  b'until': 290,
#  b'speak': 291,
#  b'far': 292,
#  b'dorothea': 293,
#  b'i,': 294,
#  b'room': 295,
#  b'mother': 296,
#  b'used': 297,
#  b'given': 298,
#  b'don\xe2\x80\x99t': 299,
#  b'certain': 300,
#  b'sort': 301,
#  b'i.': 302,
#  b'cannot': 303,
#  b'gone': 304,
#  b'mean': 305,
#  b'keep': 306,
#  b'pretty': 307,
#  b'then,': 308,
#  b'man,': 309,
#  b"it's": 310,
#  b'thing': 311,
#  b'friend': 312,
#  b'within': 313,
#  b'taking': 314,
#  b'home': 315,
#  b'why': 316,
#  b'heart': 317,
#  b'everything': 318,
#  b'coming': 319,
#  b'call': 320,
#  b'sophia': 321,
#  b'person': 322,
#  b'which,': 323,
#  b'hand,': 324,
#  b'money': 325,
#  b'light': 326,
#  b'words': 327,
#  b'aunt': 328,
#  b'them.': 329,
#  b'known': 330,
#  b'this,': 331,
#  b'each': 332,
#  b'manner': 333,
#  b'you.': 334,
#  b'world': 335,
#  b'full': 336,
#  b'help': 337,
#  b'honour': 338,
#  b'micawber': 339,
#  b'so,': 340,
#  b'here,': 341,
#  b'out,': 342,
#  b'door': 343,
#  b'moment': 344,
#  b'night': 345,
#  b'master': 346,
#  b'"but': 347,
#  b'near': 348,
#  b'course': 349,
#  b'house,': 350,
#  b'family': 351,
#  b'glad': 352,
#  b'up,': 353,
#  b'certainly': 354,
#  b'there,': 355,
#  b'reason': 356,
#  b'casaubon': 357,
#  b'ask': 358,
#  b'deal': 359,
#  b'"it': 360,
#  b'he,': 361,
#  b'feel': 362,
#  b'immediately': 363,
#  b'aunt,': 364,
#  b'received': 365,
#  b'use': 366,
#  b'means': 367,
#  b'father': 368,
#  b'\xe2\x80\x98and': 369,
#  b'sense': 370,
#  b'large': 371,
#  b'lady,': 372,
#  b'work': 373,
#  b'read': 374,
#  b'end': 375,
#  b'room,': 376,
#  b'fred': 377,
#  b'matter': 378,
#  b'stood': 379,
#  b'till': 380,
#  b'cried': 381,
#  b'seeing': 382,
#  b'ought': 383,
#  b'feeling': 384,
#  b'happy': 385,
#  b'hardly': 386,
#  b'small': 387,
#  b'again.': 388,
#  b'\xe2\x80\x98you': 389,
#  b'word': 390,
#  b'suppose': 391,
#  b'sophia,': 392,
#  b'letter': 393,
#  b'state': 394,
#  b'know,': 395,
#  b'us,': 396,
#  b'morning': 397,
#  b'leicester': 398,
#  b'years': 399,
#  b'care': 400,
#  b'business': 401,
#  b'way,': 402,
#  b'fine': 403,
#  b"can't": 404,
#  b'short': 405,
#  b'able': 406,
#  b'behind': 407,
#  b'night,': 408,
#  b'lay': 409,
#  b'does': 410,
#  b'sometimes': 411,
#  b'himself,': 412,
#  b'kept': 413,
#  b'usual': 414,
#  b'too,': 415,
#  b'therefore': 416,
#  b'turn': 417,
#  b'husband': 418,
#  b'afraid': 419,
#  b'passed': 420,
#  b'obliged': 421,
#  b'micawber,': 422,
#  b'peggotty': 423,
#  b'high': 424,
#  b'do,': 425,
#  b'allworthy': 426,
#  b'side': 427,
#  b'several': 428,
#  b'already': 429,
#  b'bulstrode': 430,
#  b'mention': 431,
#  b'bring': 432,
#  b'bad': 433,
#  b'day,': 434,
#  b'"my': 435,
#  b'but,': 436,
#  b'"that': 437,
#  b'account': 438,
#  b'remember': 439,
#  b'face,': 440,
#  b'rosamond': 441,
#  b'power': 442,
#  b'appeared': 443,
#  b'myself,': 444,
#  b'opinion': 445,
#  b'head,': 446,
#  b'subject': 447,
#  b'on,': 448,
#  b'else': 449,
#  b'above': 450,
#  b'girl': 451,
#  b'seems': 452,
#  b'fell': 453,
#  b'strong': 454,
#  b'dear,': 455,
#  b'open': 456,
#  b'it;': 457,
#  b'need': 458,
#  b'dorothea,': 459,
#  b'life,': 460,
#  b'either': 461,
#  b'knows': 462,
#  b'therefore,': 463,
#  b'richard': 464,
#  b'doubt': 465,
#  b'walked': 466,
#  b'except': 467,
#  b'she,': 468,
#  b'become': 469,
#  b'bear': 470,
#  b'well,': 471,
#  b'ready': 472,
#  b'looks': 473,
#  b'married': 474,
#  b'turning': 475,
#  b'fellow': 476,
#  b'show': 477,
#  b'who,': 478,
#  b'human': 479,
#  b'wanted': 480,
#  b'became': 481,
#  b'case': 482,
#  b'for,': 483,
#  b'order': 484,
#  b'company': 485,
#  b'general': 486,
#  b'held': 487,
#  b'laid': 488,
#  b'times': 489,
#  b'will,': 490,
#  b'spoke': 491,
#  b'sitting': 492,
#  b'thinking': 493,
#  b'observed': 494,
#  b'replied': 495,
#  b'hard': 496,
#  b'him;': 497,
#  b'"oh,': 498,
#  b'comes': 499,
#  b'low': 500,
#  b'mind,': 501,
#  b'sooner': 502,
#  b'air': 503,
#  b'not,': 504,
#  b'ada': 505,
#  b'black': 506,
#  b'change': 507,
#  b'nature': 508,
#  b'thus': 509,
#  b'voice': 510,
#  b'return': 511,
#  b'wife': 512,
#  b'point': 513,
#  b'talk': 514,
#  b'hold': 515,
#  b'understand': 516,
#  b'doing': 517,
#  b'morning,': 518,
#  b'getting': 519,
#  b'peggotty,': 520,
#  b'makes': 521,
#  b'eyes,': 522,
#  b'lydgate,': 523,
#  b'walk': 524,
#  b'idea': 525,
#  b'happened': 526,
#  b'\xe2\x80\x9cyou': 527,
#  b'"what': 528,
#  b'whatever': 529,
#  b'possible': 530,
#  b'object': 531,
#  b'bucket': 532,
#  b'question': 533,
#  b'lost': 534,
#  b'"the': 535,
#  b'live': 536,
#  b'close': 537,
#  b'entirely': 538,
#  b'sent': 539,
#  b'no,': 540,
#  b'mentioned': 541,
#  b"that's": 542,
#  b'different': 543,
#  b'"he': 544,
#  b'sorry': 545,
#  b'standing': 546,
#  b'along': 547,
#  b'manner,': 548,
#  b'presently': 549,
#  b'evening': 550,
#  b'in,': 551,
#  b'occasion': 552,
#  b'themselves': 553,
#  b'reader': 554,
#  b'instead': 555,
#  b'be,': 556,
#  b'pleased': 557,
#  b'natural': 558,
#  b'true': 559,
#  b'nay,': 560,
#  b'answer': 561,
#  b'putting': 562,
#  b'woman,': 563,
#  b'necessary': 564,
#  b'country': 565,
#  b'knowledge': 566,
#  b'neither': 567,
#  b'all,': 568,
#  b'pleasure': 569,
#  b'consider': 570,
#  b'likely': 571,
#  b'time.': 572,
#  b'rest': 573,
#  b'home,': 574,
#  b'yourself': 575,
#  b'giving': 576,
#  b'wished': 577,
#  b'saying': 578,
#  b'doctor': 579,
#  b'wonder': 580,
#  b'mother,': 581,
#  b'together': 582,
#  b'itself': 583,
#  b'five': 584,
#  b'beyond': 585,
#  b'none': 586,
#  b'lord': 587,
#  b'sir,\xe2\x80\x9d': 588,
#  b'perhaps,': 589,
#  b'hair': 590,
#  b'easily': 591,
#  b'boy': 592,
#  b'hour': 593,
#  b'desire': 594,
#  b'promise': 595,
#  b'alone': 596,
#  b'george': 597,
#  b'sit': 598,
#  b'away,': 599,
#  b'jarndyce': 600,
#  b'fire': 601,
#  b'other,': 602,
#  b'hundred': 603,
#  b'world,': 604,
#  b'sure,': 605,
#  b'carried': 606,
#  b'allworthy,': 607,
#  b'partridge': 608,
#  b'\xe2\x80\x98my': 609,
#  b'dora': 610,
#  b'mary': 611,
#  b'returns': 612,
#  b'one,': 613,
#  b'opportunity': 614,
#  b'traddles,': 615,
#  b'knowing': 616,
#  b'shook': 617,
#  b'strange': 618,
#  b'considered': 619,
#  b'also': 620,
#  b'former': 621,
#  b'entered': 622,
#  b'think,': 623,
#  b'dark': 624,
#  b'during': 625,
#  b'agnes': 626,
#  b'past': 627,
#  b'"if': 628,
#  b'interest': 629,
#  b'second': 630,
#  b'pay': 631,
#  b'chair': 632,
#  b'days': 633,
#  b'meant': 634,
#  b'greater': 635,
#  b'door,': 636,
#  b'visit': 637,
#  b'before,': 638,
#  b'conversation': 639,
#  b'shaking': 640,
#  b'expected': 641,
#  b'meet': 642,
#  b'friend,': 643,
#  b'"yes,': 644,
#  b'greatly': 645,
#  b'brother': 646,
#  b'traddles': 647,
#  b'early': 648,
#  b'western': 649,
#  b'brooke': 650,
#  b'down,': 651,
#  b'court': 652,
#  b'snagsby': 653,
#  b'perfectly': 654,
#  b'fear': 655,
#  b'it\xe2\x80\x99s': 656,
#  b'head.': 657,
#  b'heart,': 658,
#  b'regard': 659,
#  b'sir,"': 660,
#  b'perfect': 661,
#  b'acquainted': 662,
#  b'seem': 663,
#  b'arm': 664,
#  b'me;': 665,
#  b'voice,': 666,
#  b'saying,': 667,
#  b'run': 668,
#  b'write': 669,
#  b'character': 670,
#  b'resolved': 671,
#  b'others': 672,
#  b'women': 673,
#  b'lived': 674,
#  b'utmost': 675,
#  b'loved': 676,
#  b'nobody': 677,
#  b'child': 678,
#  b'easy': 679,
#  b'assure': 680,
#  b'particular': 681,
#  b'tears': 682,
#  b'truth': 683,
#  b'believed': 684,
#  b'thoughts': 685,
#  b'truth,': 686,
#  b'"no,': 687,
#  b'"well,': 688,
#  b'place,': 689,
#  b'oh,': 690,
#  b'cause': 691,
#  b'now.': 692,
#  b'guardian': 693,
#  b'squire': 694,
#  b'quiet': 695,
#  b'gentleman,': 696,
#  b'himself.': 697,
#  b'effect': 698,
#  b'unless': 699,
#  b'us.': 700,
#  b'partridge,': 701,
#  b'late': 702,
#  b'that.': 703,
#  b'blifil': 704,
#  b'met': 705,
#  b'back,': 706,
#  b'agreeable': 707,
#  b'fortune': 708,
#  b'son': 709,
#  b'marry': 710,
#  b'gentlemen': 711,
#  b'proper': 712,
#  b'fact': 713,
#  b'so.': 714,
#  b'speaking': 715,
#  b'evening,': 716,
#  b'short,': 717,
#  b'ladies': 718,
#  b'figure': 719,
#  b'copperfield,': 720,
#  b'beg': 721,
#  b'table': 722,
#  b'stay': 723,
#  b'goes': 724,
#  b'james': 725,
#  b'beginning': 726,
#  b'dare': 727,
#  b'expect': 728,
#  b'friends': 729,
#  b'hand.': 730,
#  b'together,': 731,
#  b'sister': 732,
#  b'honour,': 733,
#  b'way.': 734,
#  b'arms': 735,
#  b'trouble': 736,
#  b'man.': 737,
#  b'tried': 738,
#  b'answered,': 739,
#  b'fond': 740,
#  b'forth': 741,
#  b'further': 742,
#  b'opened': 743,
#  b'more,': 744,
#  b'her;': 745,
#  b'happiness': 746,
#  b'guppy': 747,
#  b'aunt.': 748,
#  b'\xe2\x80\x98but': 749,
#  b'murdstone': 750,
#  b'probably': 751,
#  b'act': 752,
#  b'"not': 753,
#  b'generally': 754,
#  b'thought,': 755,
#  b'\xe2\x80\x98it': 756,
#  b'common': 757,
#  b'father,': 758,
#  b'life.': 759,
#  b'believe,': 760,
#  b'fair': 761,
#  b'afterwards': 762,
#  b'eye': 763,
#  b'try': 764,
#  b'thank': 765,
#  b'clear': 766,
#  b'cousin': 767,
#  b'said.': 768,
#  b'love,': 769,
#  b'child,': 770,
#  b'children': 771,
#  b'carry': 772,
#  b'fire,': 773,
#  b'violent': 774,
#  b'takes': 775,
#  b'know.': 776,
#  b'especially': 777,
#  b'it."': 778,
#  b'\xe2\x80\x98what': 779,
#  b'possibly': 780,
#  b'longer': 781,
#  b'bed': 782,
#  b'marriage': 783,
#  b'away.': 784,
#  b'town': 785,
#  b'concerning': 786,
#  b'hours': 787,
#  b'ten': 788,
#  b'bright': 789,
#  b'beautiful': 790,
#  b'circumstances': 791,
#  b'remained': 792,
#  b'besides': 793,
#  b'daughter': 794,
#  b'agnes,': 795,
#  b'rosamond,': 796,
#  b'fellow,': 797,
#  b'difficult': 798,
#  b'length': 799,
#  b'anybody': 800,
#  b'window': 801,
#  b'\xe2\x80\x98that': 802,
#  b'creature': 803,
#  b'uncle': 804,
#  b'twenty': 805,
#  b'white': 806,
#  b'herself,': 807,
#  b'come,': 808,
#  b'ill': 809,
#  b'arrived': 810,
#  b'supposed': 811,
#  b'captain': 812,
#  b'deep': 813,
#  b'thousand': 814,
#  b'trust': 815,
#  b'tulkinghorn': 816,
#  b'middlemarch': 817,
#  b'out.': 818,
#  b'shut': 819,
#  b'worse': 820,
#  b'(for': 821,
#  b'wife,': 822,
#  b'"why,': 823,
#  b'determined': 824,
#  b'liked': 825,
#  b'pleasant': 826,
#  b'however': 827,
#  b'\xe2\x80\x9cand': 828,
#  b'walking': 829,
#  b'excellent': 830,
#  b'expression': 831,
#  b'george,': 832,
#  b"i'll": 833,
#  b'yes,': 834,
#  b'before.': 835,
#  b'particularly': 836,
#  b'likewise': 837,
#  b'see,': 838,
#  b'duty': 839,
#  b'first,': 840,
#  b'bed,': 841,
#  b'wrong': 842,
#  b'book': 843,
#  b'public': 844,
#  b'across': 845,
#  b'begin': 846,
#  b'moment,': 847,
#  b'house.': 848,
#  b'sir.': 849,
#  b'day.': 850,
#  b'engaged': 851,
#  b"won't": 852,
#  b'off,': 853,
#  b'fall': 854,
#  b'\xe2\x80\x98if': 855,
#  b'\xe2\x80\x98oh,': 856,
#  b'cold': 857,
#  b'pass': 858,
#  b'satisfaction': 859,
#  b'private': 860,
#  b'stopped': 861,
#  b'appear': 862,
#  b'worth': 863,
#  b'confidence': 864,
#  b'form': 865,
#  b'ladyship': 866,
#  b'bulstrode,': 867,
#  b'lying': 868,
#  b'chair,': 869,
#  b'corner': 870,
#  b'there.': 871,
#  b'worthy': 872,
#  b'"how': 873,
#  b'last,': 874,
#  b'according': 875,
#  b'family,': 876,
#  b'hope,': 877,
#  b'more.': 878,
#  b"i'm": 879,
#  b'\xe2\x80\x9cthat': 880,
#  b'dedlock': 881,
#  b'handsome': 882,
#  b'yet,': 883,
#  b'highly': 884,
#  b'fact,': 885,
#  b'showed': 886,
#  b'tone': 887,
#  b'talking': 888,
#  b'persons': 889,
#  b'me."': 890,
#  b'dead': 891,
#  b'was.': 892,
#  b'secret': 893,
#  b'all.': 894,
#  b'receive': 895,
#  b'passion': 896,
#  b'ran': 897,
#  b'ground': 898,
#  b'sight': 899,
#  b'excuse': 900,
#  b'dedlock,': 901,
#  b'matters': 902,
#  b'telling': 903,
#  b'words,': 904,
#  b'steerforth': 905,
#  b'thy': 906,
#  b"dorothea's": 907,
#  b"lydgate's": 908,
#  b'garth': 909,
#  b'bless': 910,
#  b'much,': 911,
#  b'too.': 912,
#  b'four': 913,
#  b'forward': 914,
#  b'living': 915,
#  b'sufficient': 916,
#  b'western,': 917,
#  b'guppy,': 918,
#  b'slowly': 919,
#  b'\xe2\x80\x98the': 920,
#  b'stand': 921,
#  b'had,': 922,
#  b'sir,\xe2\x80\x99': 923,
#  b'finding': 924,
#  b'vincy': 925,
#  b'informed': 926,
#  b'expressed': 927,
#  b'copperfield,\xe2\x80\x99': 928,
#  b'up.': 929,
#  b'heaven': 930,
#  b'imagine': 931,
#  b'plain': 932,
#  b"there's": 933,
#  b'convinced': 934,
#  b'face.': 935,
#  b'forget': 936,
#  b'attention': 937,
#  b'impossible': 938,
#  b'understood': 939,
#  b'begged': 940,
#  b'appearance': 941,
#  b'money,': 942,
#  b'presence': 943,
#  b'do.': 944,
#  b'forgive': 945,
#  b'tom': 946,
#  b'extremely': 947,
#  b'affection': 948,
#  b'express': 949,
#  b'holding': 950,
#  b'mere': 951,
#  b'step': 952,
#  b'why,': 953,
#  b'written': 954,
#  b'richard,': 955,
#  b'ladislaw': 956,
#  b'word,': 957,
#  b'table,': 958,
#  b'in.': 959,
#  b'sound': 960,
#  b'red': 961,
#  b'play': 962,
#  b'various': 963,
#  b'boy,': 964,
#  b'angry': 965,
#  b'intended': 966,
#  b'you."': 967,
#  b'hearing': 968,
#  b'exactly': 969,
#  b'suddenly': 970,
#  b'allow': 971,
#  b'story': 972,
#  b'once,': 973,
#  b'other.': 974,
#  b'cut': 975,
#  b'somebody': 976,
#  b'brother,': 977,
#  b'dinner': 978,
#  b'learned': 979,
#  b'paid': 980,
#  b'keeping': 981,
#  b'everybody': 982,
#  b'on.': 983,
#  b'fresh': 984,
#  b'here.': 985,
#  b'following': 986,
#  b'real': 987,
#  b'sudden': 988,
#  b'unfortunate': 989,
#  b'wait': 990,
#  b'consequence': 991,
#  b'greatest': 992,
#  b'send': 993,
#  b'future': 994,
#  b'guardian,': 995,
#  b'madam,\xe2\x80\x9d': 996,
#  b'smallweed': 997,
#  b'bucket,': 998,
#  b'glass': 999,
#  ...}

# %% [markdown]
# # 所有词转换成ID

# %%
word2id.get(b'easily', 0)
# Out:
# 591

# %%
data = list()
unk_count = 0
for word in text_words:
    # 全部转换成id
    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ('UNK', unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:10])
# Out:
# Words count: 1367297
# Unique words: 76390
# Vocabulary size: 9178
# Most common words: [('UNK', 135224), (b'the', 57024), (b'to', 41289), (b'and', 39944), (b'of', 35950), (b'a', 28947), (b'i', 28097), (b'in', 22601), (b'that', 17328), (b'he', 17089)]

# %% [markdown]
# # 构建所需训练数据

# %%
data_index = 0

def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # get window size (words left and right + current one)
    span = 2 * skip_window + 1  # 7为窗口，左3右3中间1
    buffer = collections.deque(maxlen=span)   # 创建一个长度为7的队列
    if data_index + span > len(data):       # 如果数据被滑完一遍了，就置为0，重新开始
        data_index = 0
    buffer.extend(data[data_index:data_index+span])      # 队列存的是当前窗口，例如deque（[28, 75, 37, 6, 195, 2, 343], maxlen=7）,deque存的是id
    data_index += span
    for i in range(batch_size // num_skips):       # num_skip表示取多少组不同的词作为输出，此例为2
        context_words = [w for w in range(span) if w != skip_window]  # 上下文就是[0,1,2,4,5,6],每次循环，只是里面的数变了
        words_to_use = random.sample(context_words, num_skips)   # 在上下文里随机选2个候选词
        for j, context_words in enumerate(words_to_use): # 遍历每一个候选词，用其当作输出也就是标签
            batch[i * num_skips + j] = buffer[skip_window]   # 输入都为当前窗口的中间此，即3
            labels[i * num_skips + j, 0] = buffer[context_words]   # 用当前候选词当作标签
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])  # 之前已经传入7歌词了，窗口要右移了，例如[28, 75, 37, 6, 195, 2, 343]-》[75, 37, 6, 195, 2, 343，124]
    
   # (7+10000-2)%10000，净搞这种原本很简单，加上之后让人看不懂的写法
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
random.sample([0,1,2,4,5,6], 2)
# Out:
# [0, 6]

# %%
vocabulary_size, embedding_size
# Out:
# (9178, 200)

# %%
with tf.device('/cpu:0'):
    embedding = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))   # 维度(9178, 200)
    nce_weights = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# %% [markdown]
# # 通过tf.nn.embedding_lookup函数将索引转换成词向量

# %%
def get_embedding(x):
    with tf.device('/cpu:0'):
        # 将x对应的embedding向量从embedding里面拿出来
        x_embed = tf.nn.embedding_lookup(embedding, x)
        return x_embed

# %% [markdown]
# # 损失函数定义
# 先分别计算出正样本和采样出的负样本对应的output和label\
# 再通过sigmoid cross entropy 来极端output和label的loss

# %%
def nce_loss(x_embed, y):
    with tf.device('/cpu:0'):
        y = tf.cast(y, tf.int64)
        loss = tf.reduce_mean(
            tf.nn.nce_loss(weights=nce_weights,
                           biases=nce_biases,
                           labels=y,
                           inputs=x_embed,
                           num_sampled=num_sampled,   # 采样出多少个负样本
                           num_classes=vocabulary_size
                          )
        )

        return loss

# %% [markdown]
# # 测试观察模块

# %%
def evaluate(x_embed):
    with tf.device('/cpu:0'):
        x_embed = tf.cast(x_embed, tf.float32)
        x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))   # 归一化
        embedding_norm = embedding / tf.sqrt(tf.reduce_mean(tf.square(embedding), 1, keepdims=True), tf.float32)  # 全部向量的
        cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True)  # 计算余弦相似度
        return cosine_sim_op
    
    # SGD
optimizer = tf.optimizers.SGD(learning_rate)

# %%
# 迭代优化
def run_oprimization(x, y):
    with tf.device('/gpu:0'):
        with tf.GradientTape() as g:
            emb = get_embedding(x)
            loss = nce_loss(emb, y)
            
        # 计算梯度
        gradients = g.gradient(loss, [embedding, nce_weights, nce_biases])
        
        # 更新
        optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))

# %%
# 待测试的几个词
x_test = np.array([word2id[w.encode('utf-8')] for w in eval_words])

# 训练
for step in range(1, num_steps + 1):
    batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
    run_oprimization(batch_x, batch_y)
    
    if step % display_step == 0 or step == 1:
        loss = nce_loss(get_embedding(batch_x), batch_y)
        print("step: %i, loss: %f" % (step, loss))
        
    if step % eval_step == 0 or step == 1:
        print("Evaluation...")
        sim = evaluate(get_embedding(x_test)).numpy()
        for i in range(len(eval_words)):
            topk = 8  # 返回前8个最相似的
            nearest = (-sim[i, :]).argsort()[1:topk + 1]
            log_str = '"%s" nearst neighbors:' % eval_words[i]
            for k in range(topk):
                log_str = '%s %s,' % (log_str, id2word[nearest[k]])
                
            print(log_str)
# Out:
# step: 1, loss: 411.873840
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 20000, loss: 0.207698
# step: 40000, loss: 0.204800
# step: 60000, loss: 0.148185
# step: 80000, loss: 0.166082
# step: 100000, loss: 0.095348
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 120000, loss: 0.991273
# step: 140000, loss: 1.231690
# step: 160000, loss: 0.162215
# step: 180000, loss: 0.140424
# step: 200000, loss: 0.194818
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 220000, loss: 0.078625
# step: 240000, loss: 0.138167
# step: 260000, loss: 0.164712
# step: 280000, loss: 0.191730
# step: 300000, loss: 0.143969
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 320000, loss: 0.127009
# step: 340000, loss: 0.179292
# step: 360000, loss: 2.551472
# step: 380000, loss: 0.100407
# step: 400000, loss: 0.219178
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 420000, loss: 0.113256
# step: 440000, loss: 0.127525
# step: 460000, loss: 0.168805
# step: 480000, loss: 0.145033
# step: 500000, loss: 0.145981
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 520000, loss: 1.121348
# step: 540000, loss: 0.128913
# step: 560000, loss: 0.222977
# step: 580000, loss: 0.135507
# step: 600000, loss: 0.206743
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 620000, loss: 0.148377
# step: 640000, loss: 0.165206
# step: 660000, loss: 0.130682
# step: 680000, loss: 0.072253
# step: 700000, loss: 0.083751
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 720000, loss: 0.403469
# step: 740000, loss: 0.100764
# step: 760000, loss: 0.148254
# step: 780000, loss: 2.997600
# step: 800000, loss: 0.175950
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 820000, loss: 0.104319
# step: 840000, loss: 1.478620
# step: 860000, loss: 0.203589
# step: 880000, loss: 0.221015
# step: 900000, loss: 0.258778
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',
# step: 920000, loss: 0.207054
# step: 940000, loss: 0.057061
# step: 960000, loss: 0.237116
# step: 980000, loss: 0.455017
# step: 1000000, loss: 0.200503
# Evaluation...
# "nine" nearst neighbors: b'believes', b'combined', b'harsh', b'refused', b'\xe2\x80\x98all', b'fact,', b'going.', b'request',
# "of" nearst neighbors: b'distance', b'chamber,', b'happy', b'jarndyce,', b'hospital,', b'disposition', b'begged', b'(as',
# "going" nearst neighbors: b'general,', b'drawers', b'except', b'nephew,', b'sore', b'tea', b'horrible', b'stayed',
# "girl" nearst neighbors: b'adore', b'flite,', b'degrees,', b'become', b'other."', b'room.', b'\xe2\x80\x9ci', b'hinder',
# "love" nearst neighbors: b'thwackum,', b'garden', b'northerton', b'a-going', b"'my", b'trial', b'case.', b'aside',

# %%
1、云会计模型配置沟通，并在模型平台上配置了3个行业6个财务维度共计18个模型。
2、定时任务相关问题沟通讲解，就git拉入服务器导致的一些跑批任务bug进行修复。
3、
